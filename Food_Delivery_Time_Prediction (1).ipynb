# %%
import pandas as pd

df = pd.read_csv("https://github.com/Patil-Sravani/food_delivery_time_prediction/raw/refs/heads/main/Food_Delivery_Time_Prediction.csv")

# %%
df.head()
# Out:
#     Order_ID  Order_Date  Order_Hour Day_of_Week  Is_Weekend  Is_Festival  \
# 0  ORD000001  2025-10-28           8     Tuesday           0            0
# 1  ORD000002  2025-09-26          12      Friday           0            0
# 2  ORD000003  2025-01-26          18      Sunday           1            0
# 3  ORD000004  2025-11-19          12   Wednesday           0            0
# 4  ORD000005  2025-08-04          18      Monday           0            0
#
#   Weather  Pickup_Zone Dropoff_Zone Vehicle_Type  ...  Order_Items  \
# 0   Clear          CBD   Commercial      Scooter  ...            1
# 1    Rain          CBD          CBD      Scooter  ...            3
# 2   Clear  Residential  Residential      Scooter  ...            1
# 3  Cloudy  Residential   Industrial         Bike  ...            3
# 4    Rain   Industrial  Residential         Bike  ...            1
#
#    Restaurant_Load  Preparation_Time_Min Road_Distance_km  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Order_ID                    50000 non-null  str
#  1   Order_Date                  50000 non-null  str
#  2   Order_Hour                  50000 non-null  int64
#  3   Day_of_Week                 50000 non-null  str
#  4   Is_Weekend                  50000 non-null  int64
#  5   Is_Festival                 50000 non-null  int64
#  6   Weather                     50000 non-null  str
#  7   Pickup_Zone                 50000 non-null  str
#  8   Dropoff_Zone                50000 non-null  str
#  9   Vehicle_Type                50000 non-null  str
#  10  Rider_Experience_Years      50000 non-null  float64
#  11  Rider_Rating                50000 non-null  float64
#  12  Restaurant_Rating           50000 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Order_Hour    Is_Weekend   Is_Festival  Rider_Experience_Years  \
# count  50000.000000  50000.000000  50000.000000            50000.000000
# mean      13.847700      0.283600      0.049100                4.439744
# std        5.525291      0.450749      0.216079                2.927752
# min        0.000000      0.000000      0.000000                0.100000
# 25%       10.000000      0.000000      0.000000                2.200000
# 50%       14.000000      0.000000      0.000000                3.800000
# 75%       19.000000      1.000000      0.000000                5.900000
# max       23.000000      1.000000      1.000000               15.000000
#
#        Rider_Rating  Restaurant_Rating   Order_Items  Preparation_Time_Min  \
# count  50000.000000       50000.000000  50000.000000           50000.00000
# mean       3.951646           4.175368      2.652740              24.03118
# std        0.294960           0.356201      1.590359               8.34877
# ...

# %%
df.describe(include='all')
# Out:
#          Order_ID  Order_Date    Order_Hour Day_of_Week    Is_Weekend  \
# count       50000       50000  50000.000000       50000  50000.000000
# unique      50000         365           NaN           7           NaN
# top     ORD000001  2025-02-12           NaN     Tuesday           NaN
# freq            1         170           NaN        7264           NaN
# mean          NaN         NaN     13.847700         NaN      0.283600
# std           NaN         NaN      5.525291         NaN      0.450749
# min           NaN         NaN      0.000000         NaN      0.000000
# 25%           NaN         NaN     10.000000         NaN      0.000000
# 50%           NaN         NaN     14.000000         NaN      0.000000
# 75%           NaN         NaN     19.000000         NaN      1.000000
# max           NaN         NaN     23.000000         NaN      1.000000
#
#          Is_Festival Weather  Pickup_Zone Dropoff_Zone Vehicle_Type  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID                      0
# Order_Date                    0
# Order_Hour                    0
# Day_of_Week                   0
# Is_Weekend                    0
# Is_Festival                   0
# Weather                       0
# Pickup_Zone                   0
# Dropoff_Zone                  0
# Vehicle_Type                  0
# Rider_Experience_Years        0
# Rider_Rating                  0
# Restaurant_Rating             0
# Cuisine_Type                  0
# Order_Items                   0
# Restaurant_Load               0
# Preparation_Time_Min          0
# Road_Distance_km              0
# Delivery_Distance_Category    0
# Traffic_Level                 0
# Number_of_Signals             0
# Average_Speed_kmph            0
# Delivery_Priority             0
# Time_taken_min                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Order_Hour', 'Day_of_Week', 'Is_Weekend',
#        'Is_Festival', 'Weather', 'Pickup_Zone', 'Dropoff_Zone', 'Vehicle_Type',
#        'Rider_Experience_Years', 'Rider_Rating', 'Restaurant_Rating',
#        'Cuisine_Type', 'Order_Items', 'Restaurant_Load',
#        'Preparation_Time_Min', 'Road_Distance_km',
#        'Delivery_Distance_Category', 'Traffic_Level', 'Number_of_Signals',
#        'Average_Speed_kmph', 'Delivery_Priority', 'Time_taken_min'],
#       dtype='str')

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['order_id', 'order_date', 'order_hour', 'day_of_week', 'is_weekend',
#        'is_festival', 'weather', 'pickup_zone', 'dropoff_zone', 'vehicle_type',
#        'rider_experience_years', 'rider_rating', 'restaurant_rating',
#        'cuisine_type', 'order_items', 'restaurant_load',
#        'preparation_time_min', 'road_distance_km',
#        'delivery_distance_category', 'traffic_level', 'number_of_signals',
#        'average_speed_kmph', 'delivery_priority', 'time_taken_min'],
#       dtype='str')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.rename(columns={'time_taken_min':'delivery_time'},inplace=True)
df.columns
# Out:
# Index(['order_id', 'order_date', 'order_hour', 'day_of_week', 'is_weekend',
#        'is_festival', 'weather', 'pickup_zone', 'dropoff_zone', 'vehicle_type',
#        'rider_experience_years', 'rider_rating', 'restaurant_rating',
#        'cuisine_type', 'order_items', 'restaurant_load',
#        'preparation_time_min', 'road_distance_km',
#        'delivery_distance_category', 'traffic_level', 'number_of_signals',
#        'average_speed_kmph', 'delivery_priority', 'delivery_time'],
#       dtype='str')

# %%
# create a column vehicle type
vehicle = df['vehicle_type'].value_counts()
vehicle
# Out:
# vehicle_type
# Bike                22943
# Scooter             12895
# Electric Scooter     8852
# Bicycle              5310
# Name: count, dtype: int64

# %%
df[['day_of_week','order_items']].head(10)
# Out:
#   day_of_week  order_items
# 0     Tuesday            1
# 1      Friday            3
# 2      Sunday            1
# 3   Wednesday            3
# 4      Monday            1
# 5   Wednesday            1
# 6     Tuesday            5
# 7      Friday            3
# 8    Thursday            3
# 9      Friday            6

# %%
df[['vehicle_type','rider_rating']].head(10)
# Out:
#        vehicle_type  rider_rating
# 0           Scooter           3.8
# 1           Scooter           3.6
# 2           Scooter           3.9
# 3              Bike           3.9
# 4              Bike           4.4
# 5  Electric Scooter           3.5
# 6           Bicycle           4.0
# 7  Electric Scooter           3.7
# 8              Bike           4.4
# 9              Bike           4.3

# %%
df[['cuisine_type','preparation_time_min']].head(10)
# Out:
#    cuisine_type  preparation_time_min
# 0         Pizza                    23
# 1      Desserts                    11
# 2       Biryani                    31
# 3        Burger                    19
# 4      Desserts                     7
# 5  South Indian                    16
# 6        Bakery                    13
# 7        Burger                    23
# 8  North Indian                    33
# 9      Desserts                    18

# %%
df[['pickup_zone','dropoff_zone']].head(10)
# Out:
#    pickup_zone dropoff_zone
# 0          CBD   Commercial
# 1          CBD          CBD
# 2  Residential  Residential
# 3  Residential   Industrial
# 4   Industrial  Residential
# 5          CBD     Suburban
# 6   Commercial   Commercial
# 7          CBD  Residential
# 8          CBD  Residential
# 9   Commercial  Residential

# %%
df[['order_hour','vehicle_type','traffic_level','delivery_time']].head(10)
# Out:
#    order_hour      vehicle_type traffic_level  delivery_time
# 0           8           Scooter      Moderate             91
# 1          12           Scooter      Moderate             21
# 2          18           Scooter      Moderate             52
# 3          12              Bike           Low             59
# 4          18              Bike      Moderate             75
# 5          18  Electric Scooter      Moderate            105
# 6          12           Bicycle           Low            180
# 7          22  Electric Scooter           Low             37
# 8           8              Bike          High            110
# 9          16              Bike           Low             69

# %%
df[(df['vehicle_type']=='Bike') & (df['delivery_time']<20)].head()
# Out:
#        order_id  order_date  order_hour day_of_week  is_weekend  is_festival  \
# 1265  ORD001266  2025-09-30          20     Tuesday           0            0
# 2510  ORD002511  2025-01-23          19    Thursday           0            0
# 3619  ORD003620  2025-09-13          16    Saturday           1            0
# 3701  ORD003702  2025-12-04           0    Thursday           0            0
# 4846  ORD004847  2025-12-05          20      Friday           0            0
#
#      weather  pickup_zone dropoff_zone vehicle_type  ...  order_items  \
# 1265   Clear  Residential     Suburban         Bike  ...            1
# 2510   Clear   Commercial          CBD         Bike  ...            1
# 3619   Clear  Residential   Commercial         Bike  ...            1
# 3701  Cloudy  Residential   Industrial         Bike  ...            1
# 4846   Clear     Suburban     Suburban         Bike  ...            1
#
#       restaurant_load  preparation_time_min road_distance_km  \
# ...

# %%
df[(df['weather']=='Rain') & (df['traffic_level']=='High')].head(10)
# Out:
#       order_id  order_date  order_hour day_of_week  is_weekend  is_festival  \
# 21   ORD000022  2025-01-25          15    Saturday           1            1
# 25   ORD000026  2025-03-02          20      Sunday           1            0
# 42   ORD000043  2025-01-12          19      Sunday           1            0
# 79   ORD000080  2025-02-22          12    Saturday           1            0
# 104  ORD000105  2025-03-06          18    Thursday           0            1
# 111  ORD000112  2025-12-19          18      Friday           0            0
# 188  ORD000189  2025-06-21          20    Saturday           1            0
# 189  ORD000190  2025-06-01          14      Sunday           1            0
# 199  ORD000200  2025-10-31          21      Friday           0            1
# 217  ORD000218  2025-08-31          18      Sunday           1            0
#
#     weather  pickup_zone dropoff_zone      vehicle_type  ...  order_items  \
# ...

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# Step 1: Connect to PostgreSQL
# Replace placeholders with your actual details
username = "postgres"      # default user
password = "venkat" # the password you set during installation
host = "localhost"         # if running locally
port = "5432"              # default PostgreSQL port
database = "food_delivery"    # the database you created in pgAdmin

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 2: Load DataFrame into PostgreSQL
table_name = "food_delivery"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'food_delivery' in database 'food_delivery'.
